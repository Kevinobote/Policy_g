# %%
import os
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup

# URL of the webpage containing PDF links
url = 'https://new.kenyalaw.org/akn/ke/act/2016/34/eng@2022-12-31'

# Create a "forestry" folder in the root directory
root_folder = os.getcwd()  # Get the current working directory
folder_location = os.path.join(root_folder, 'forestry')
if not os.path.exists(folder_location):
    os.makedirs(folder_location)

# Fetch the content of the webpage
response = requests.get(url)
response.raise_for_status()  # Check for request errors

# Parse the webpage content
soup = BeautifulSoup(response.text, 'html.parser')

# Find all links ending with .pdf
pdf_links = soup.find_all('a', href=lambda href: href and href.lower().endswith('.pdf'))

for link in pdf_links:
    # Get the full URL of the PDF file
    pdf_url = urljoin(url, link['href'])
    # Get the filename by splitting the URL path
    filename = os.path.join(folder_location, os.path.basename(link['href']))
    # Download the PDF file
    with requests.get(pdf_url, stream=True) as pdf_response:
        pdf_response.raise_for_status()
        with open(filename, 'wb') as pdf_file:
            for chunk in pdf_response.iter_content(chunk_size=8192):
                if chunk:
                    pdf_file.write(chunk)
    print(f'Downloaded: {filename}')

# %%
import os
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup

# URL of the webpage containing PDF links
url = 'https://new.kenyalaw.org/akn/ke/act/2016/34/eng@2022-12-31'

# Create a "forestry" folder in the root directory
root_folder = os.getcwd()  # Get the current working directory
folder_location = os.path.join(root_folder, 'forestry')
if not os.path.exists(folder_location):
    os.makedirs(folder_location)

# Fetch the content of the webpage
response = requests.get(url)
response.raise_for_status()  # Check for request errors

# Parse the webpage content
soup = BeautifulSoup(response.text, 'html.parser')

# Debug: Print the content fetched
print("Webpage content fetched successfully.")

# Debug: Print all links found
print("Links found on the page:")
all_links = soup.find_all('a', href=True)
for link in all_links:
    print(link['href'])

# Find and filter links ending with .pdf
pdf_links = soup.find_all('a', href=lambda href: href and href.lower().endswith('.pdf'))

if not pdf_links:
    print("No PDF links found.")
else:
    print(f"Found {len(pdf_links)} PDF link(s):")

for link in pdf_links:
    # Get the full URL of the PDF file
    pdf_url = urljoin(url, link['href'])
    # Get the filename by splitting the URL path
    filename = os.path.join(folder_location, os.path.basename(link['href']))
    # Download the PDF file
    try:
        with requests.get(pdf_url, stream=True) as pdf_response:
            pdf_response.raise_for_status()
            with open(filename, 'wb') as pdf_file:
                for chunk in pdf_response.iter_content(chunk_size=8192):
                    if chunk:
                        pdf_file.write(chunk)
        print(f'Downloaded: {filename}')
    except Exception as e:
        print(f"Failed to download {pdf_url}: {e}")
# Out:
# Webpage content fetched successfully.
# Links found on the page:
# #top
# #main-nav
# #search
# https://kenyalaw.org/kl/index.php?id=115
# https://kenyalaw.org/kl/index.php?id=157
# https://kenyalaw.org/kl/index.php?id=1990
# https://kenyalaw.org/kl/index.php?id=2003
# https://kenyalaw.org/kl/index.php?id=3158
# https://kenyalaw.org/kl/index.php?id=3386
# https://kenyalaw.org/kl/
# /
# https://kenyalaw.org/kl/
# /judgments/
# /legislation/
# /akn/ke/act/2010/constitution
